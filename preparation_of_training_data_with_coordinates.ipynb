# %%
import pandas as pd
import numpy as np

# %%
import os


directory = 'boxes_transcripts_labels'

# Initialize an empty list to store the DataFrames
dataframes = []

# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.tsv'):
        # Construct the full file path
        file_path = os.path.join(directory, filename)
        
        
        df = pd.read_csv(file_path, sep=',', header=None)
        
        # Assign column names
        df.columns = ['start_index', 'end_index', 'x_top_left', 'y_top_left', 'x_bottom_right', 'y_bottom_right', 'transcript', 'field']
        
        # Add a new column for the file name
        df['file_name'] = filename
        
        # Append the DataFrame to the list
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df.sample(6)
# Out:
#         start_index  end_index  x_top_left  y_top_left  x_bottom_right  \
# 196187            0          0        1685         986            1748
# 141257        10935      10939        1381        1505            1442
# 127110        24646      24654         733        2451             799
# 199683         5466       5473         681        1551             790
# 196555         6385       6388         507        1385             549
# 60490         11902      11917        1824        2433            2039
#
#         y_bottom_right        transcript  field  \
# 196187            1024           8285.66  OTHER
# 141257            1529             09133  OTHER
# 127110            2484         1545-0008  OTHER
# 199683            1588          Internal  OTHER
# 196555            1417              Plan  OTHER
# 60490             2464  Katherinechester  OTHER
#
#                                                 file_name
# 196187  dc1469ce-6c5d-47a1-b06c-940c46e741fe_document-...
# 141257  a3283f46-84e8-46db-a456-44e2d4c5e256_document-...
# 127110  96d70235-d9ea-4a83-92ed-e3de4606a00f_document-...
# 199683  ddaf85bc-85ed-4812-9100-b1a83a858d2b_document-...
# 196555  dc1469ce-6c5d-47a1-b06c-940c46e741fe_document-...
# 60490   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...

# %%
combined_df.isna().sum()
# Out:
# start_index        0
# end_index          0
# x_top_left         0
# y_top_left         0
# x_bottom_right     0
# y_bottom_right     0
# transcript        58
# field              0
# file_name          0
# dtype: int64

# %%
combined_df[combined_df['transcript'].isna() == True]
# Out:
#         start_index  end_index  x_top_left  y_top_left  x_bottom_right  \
# 11225          4133       4135        1680         961            1713
# 17836          2237       2239         111         280             132
# 19974          6467       6468        1623         689            1653
# 19978          6638       6639        1288         722            1318
# 21900          5021       5022        1592         673            1622
# 30726          4309       4310        1990         962            2026
# 32573          4365       4366        1678         963            1714
# 38251          4832       4833        1315         652            1344
# 39748          4297       4298        1678         963            1714
# 39752          4587       4589        1990         959            2026
# 40666          4429       4431        1989         960            2026
# 48475          6188       6189        1368         711            1400
# 49332          6114       6115        1277         703            1308
# 51261          7175       7176        1480         835            1516
# 51308          8528       8529        1809         898            1845
# 57237          4205       4207        1990         961            2024
# 58166          4544       4545        1578         957            1621
# 58169          4818       4820        1990         961            2023
# 60012          4119       4121        1680         964            1713
# 60897          3842       3843        1581         953            1616
# 60915          4057       4058        1678         963            1715
# 91531          4688       4690        1990         960            2025
# 91538          4868       4869        1678         963            1715
# 93865          5331       5332        1570         662            1598
# 99064          4904       4906        1990         961            2026
# 102304         4539       4541        1678         962            1713
# 102313         4719       4721        1990         960            2024
# 103207         3894       3896        1678         961            1714
# 105045         4208       4209        1677         963            1716
# 105052         4694       4696        1991         962            2025
# 123373         5329       5331        1571         662            1599
# 125546         6287       6288        1371         765            1405
# 125548         6293       6294        1454         768            1490
# 125565         6772       6773        1710         791            1741
# 126420         5208       5209        1641         702            1672
# 126425         5390       5391        1385         730            1417
# 135209         4627       4629        1990         960            2026
# 135223         4833       4835        1679         962            1714
# 141787         6761       6762        1401         786            1436
# 141800         7046       7047        1737         815            1768
# 149402         4404       4405        1580         959            1619
# 149405         4458       4460        1990         961            2025
# 157416         4759       4760        1315         654            1344
# 165630         5127       5129        1990         961            2024
# 171614         4319       4321        1991         959            2025
# 176790         8205       8207        1787         868            1820
# 184640         4143       4145        1262         673            1295
# 195529         4213       4214        1655         711            1684
# 198241         4688       4690        1990         960            2025
# 198248         4868       4869        1678         963            1715
# 204422         4556       4557        1572         654            1599
# 205495         6799       6801        1508         810            1542
# 205528         7494       7495        1760         845            1796
# 208264         6133       6134        1387         732            1415
# 210210         8464       8465        1834         923            1868
# 223247         4432       4434        1234         660            1265
# 228803         4181       4182        1679         953            1710
# 228825         4459       4461        1990         961            2025
#
#         y_bottom_right transcript  field  \
# 11225              988        NaN  OTHER
# 17836              302        NaN  OTHER
# 19974              711        NaN  OTHER
# 19978              748        NaN  OTHER
# 21900              696        NaN  OTHER
# 30726              987        NaN  OTHER
# 32573              992        NaN  OTHER
# 38251              674        NaN  OTHER
# 39748              992        NaN  OTHER
# 39752              987        NaN  OTHER
# 40666              988        NaN  OTHER
# 48475              736        NaN  OTHER
# 49332              727        NaN  OTHER
# 51261              866        NaN  OTHER
# 51308              929        NaN  OTHER
# 57237              986        NaN  OTHER
# 58166              995        NaN  OTHER
# 58169              985        NaN  OTHER
# 60012              988        NaN  OTHER
# 60897              981        NaN  OTHER
# 60915              994        NaN  OTHER
# 91531              987        NaN  OTHER
# 91538              993        NaN  OTHER
# 93865              682        NaN  OTHER
# 99064              988        NaN  OTHER
# 102304             990        NaN  OTHER
# 102313             986        NaN  OTHER
# 103207             990        NaN  OTHER
# 105045             995        NaN  OTHER
# 105052             989        NaN  OTHER
# 123373             683        NaN  OTHER
# 125546             796        NaN  OTHER
# 125548             799        NaN  OTHER
# 125565             815        NaN  OTHER
# 126420             727        NaN  OTHER
# 126425             755        NaN  OTHER
# 135209             988        NaN  OTHER
# 135223             990        NaN  OTHER
# 141787             817        NaN  OTHER
# 141800             839        NaN  OTHER
# 149402             991        NaN  OTHER
# 149405             988        NaN  OTHER
# 157416             674        NaN  OTHER
# 165630             987        NaN  OTHER
# 171614             986        NaN  OTHER
# 176790             895        NaN  OTHER
# 184640             699        NaN  OTHER
# 195529             733        NaN  OTHER
# 198241             987        NaN  OTHER
# 198248             993        NaN  OTHER
# 204422             674        NaN  OTHER
# 205495             836        NaN  OTHER
# 205528             876        NaN  OTHER
# 208264             754        NaN  OTHER
# 210210             952        NaN  OTHER
# 223247             683        NaN  OTHER
# 228803             985        NaN  OTHER
# 228825             988        NaN  OTHER
#
#                                                 file_name
# 11225   0e997ed9-76ba-4124-ac89-38e870352902_document-...
# 17836   1606c134-52e6-47cc-bd76-64b0ecaa4157_document-...
# 19974   180a608b-321d-418b-9643-5ca2bc934dcb_document-...
# 19978   180a608b-321d-418b-9643-5ca2bc934dcb_document-...
# 21900   180a608b-321d-418b-9643-5ca2bc934dcb_document-...
# 30726   2e2254f8-7714-4ffe-bacb-0c63420c2265_document-...
# 32573   2e2254f8-7714-4ffe-bacb-0c63420c2265_document-...
# 38251   313f76e5-31db-47ad-87cd-4fb3126702af_document-...
# 39748   3546f5d8-2b0a-4ccf-89dc-4b074d0fcc74_document-...
# 39752   3546f5d8-2b0a-4ccf-89dc-4b074d0fcc74_document-...
# 40666   3546f5d8-2b0a-4ccf-89dc-4b074d0fcc74_document-...
# 48475   397ff4e6-dd98-4a94-9012-2a6138dc0a40_document-...
# 49332   397ff4e6-dd98-4a94-9012-2a6138dc0a40_document-...
# 51261   397ff4e6-dd98-4a94-9012-2a6138dc0a40_document-...
# 51308   397ff4e6-dd98-4a94-9012-2a6138dc0a40_document-...
# 57237   405509df-6488-4eb2-b453-1f4811bdb8dd_document-...
# 58166   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...
# 58169   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...
# 60012   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...
# 60897   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...
# 60915   416fcd9b-6c0e-4697-9ea2-ad7b4d7906fb_document-...
# 91531   6c8a7384-8c03-4855-8be2-e57f76363354_document-...
# 91538   6c8a7384-8c03-4855-8be2-e57f76363354_document-...
# 93865   6cfa311f-f7d9-4ffa-8710-c817e9ab3ed7_document-...
# 99064   72c9830e-3a04-40bd-b75d-0feffc3f3350_document-...
# 102304  750c0c12-75fc-48ef-bfea-36ada85af2bc_document-...
# 102313  750c0c12-75fc-48ef-bfea-36ada85af2bc_document-...
# 103207  750c0c12-75fc-48ef-bfea-36ada85af2bc_document-...
# 105045  750c0c12-75fc-48ef-bfea-36ada85af2bc_document-...
# 105052  750c0c12-75fc-48ef-bfea-36ada85af2bc_document-...
# 123373  8ffac54a-c836-41d0-baba-c0d8cb84711a_document-...
# 125546  8ffac54a-c836-41d0-baba-c0d8cb84711a_document-...
# 125548  8ffac54a-c836-41d0-baba-c0d8cb84711a_document-...
# 125565  8ffac54a-c836-41d0-baba-c0d8cb84711a_document-...
# 126420  96d70235-d9ea-4a83-92ed-e3de4606a00f_document-...
# 126425  96d70235-d9ea-4a83-92ed-e3de4606a00f_document-...
# 135209  9d9c6fdf-8de5-4bb8-8dbd-fc45a0eea3ef_document-...
# 135223  9d9c6fdf-8de5-4bb8-8dbd-fc45a0eea3ef_document-...
# 141787  a3283f46-84e8-46db-a456-44e2d4c5e256_document-...
# 141800  a3283f46-84e8-46db-a456-44e2d4c5e256_document-...
# 149402  ab1bc279-5c09-4345-ae04-52c1d9eb5048_document-...
# 149405  ab1bc279-5c09-4345-ae04-52c1d9eb5048_document-...
# 157416  ade6b1ab-031b-4857-bab3-69959098c7e3_document-...
# 165630  b5132946-40d0-40bd-9b2e-9368e802769b_document-...
# 171614  bbd90b3d-85aa-45c2-ab73-f265fb2bc89b_document-...
# 176790  bfc0d006-074a-4110-84dd-81fbaaca0285_document-...
# 184640  d1525a1d-d1c3-42ec-b340-12b6a9c6fb56_document-...
# 195529  dbc4be3a-a57a-454c-9295-568e144a54c6_document-...
# 198241  dc2ca0e2-b49a-41a6-8b1c-a675c2781b6e_document-...
# 198248  dc2ca0e2-b49a-41a6-8b1c-a675c2781b6e_document-...
# 204422  e1d34bf3-4897-45ea-83fb-dd6e383bff02_document-...
# 205495  e1d34bf3-4897-45ea-83fb-dd6e383bff02_document-...
# 205528  e1d34bf3-4897-45ea-83fb-dd6e383bff02_document-...
# 208264  e22db5e7-1361-47e8-a1bf-0a3f2b34002c_document-...
# 210210  e22db5e7-1361-47e8-a1bf-0a3f2b34002c_document-...
# 223247  ef630989-4d33-4d26-bf80-9ffece13fc5d_document-...
# 228803  f43703f3-f0c9-48bd-96fe-7ea268625e97_document-...
# 228825  f43703f3-f0c9-48bd-96fe-7ea268625e97_document-...

# %%
combined_df['transcript'] = combined_df['transcript'].fillna("NULL")

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237616 entries, 0 to 237615
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   start_index     237616 non-null  int64
#  1   end_index       237616 non-null  int64
#  2   x_top_left      237616 non-null  int64
#  3   y_top_left      237616 non-null  int64
#  4   x_bottom_right  237616 non-null  int64
#  5   y_bottom_right  237616 non-null  int64
#  6   transcript      237616 non-null  object
#  7   field           237616 non-null  object
#  8   file_name       237616 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 16.3+ MB

# %%
combined_df.to_csv("training_data_with_coordinates_final.csv")

# %%
combined_df.shape
# Out:
# (237616, 9)

# %%
combined_df.iloc[18]
# Out:
# start_index                                                     272
# end_index                                                       272
# x_top_left                                                      955
# y_top_left                                                       14
# x_bottom_right                                                  973
# y_bottom_right                                                   39
# transcript                                                        ~
# field                                                         OTHER
# file_name         004a4c67-561d-4d9c-9ef2-47cb15fbdf08_document-...
# Name: 18, dtype: object
