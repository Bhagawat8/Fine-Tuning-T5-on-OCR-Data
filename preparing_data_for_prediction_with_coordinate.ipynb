# %%
import pandas as pd
import numpy as np

# %%
import os

directory = 'boxes_transcripts'


dataframes = []

for filename in os.listdir(directory):
    if filename.endswith('.tsv'):

        file_path = os.path.join(directory, filename)
        

        df = pd.read_csv(file_path, sep=',', header=None)
        
        # Assign column names
        df.columns = ['start_index', 'end_index', 'x_top_left', 'y_top_left', 'x_bottom_right', 'y_bottom_right', 'transcript']
        
        # Add a new column for the file name
        df['file_name'] = filename
        
        # Append the DataFrame to the list
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df.sample(6)
# Out:
#        start_index  end_index  x_top_left  y_top_left  x_bottom_right  \
# 39132        15769      15769        1719        2778            1726
# 21430        11390      11392        1360        2175            1390
# 52424        13234      13238        1315        2502            1346
# 71621          682        684         209         144             248
# 30425         1934       1934        1569        2239            1594
# 27344         7656       7657         907        1006             920
#
#        y_bottom_right transcript  \
# 39132            2805          2
# 21430            2205        box
# 52424            2533      tips.
# 71621             167        Inc
# 30425            2282          x
# 27344            1027         to
#
#                                                file_name
# 39132  8b2661c7-2fdb-414d-af15-f9a5b95af261_document-...
# 21430  405509df-6488-4eb2-b453-1f4811bdb8dd_document-...
# 52424  b4040ec4-f7fc-4016-a4d4-715022b20eea_document-...
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80453 entries, 0 to 80452
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   start_index     80453 non-null  int64
#  1   end_index       80453 non-null  int64
#  2   x_top_left      80453 non-null  int64
#  3   y_top_left      80453 non-null  int64
#  4   x_bottom_right  80453 non-null  int64
#  5   y_bottom_right  80453 non-null  int64
#  6   transcript      80437 non-null  object
#  7   file_name       80453 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 4.9+ MB

# %%
combined_df[combined_df['transcript'].isna() == True]
# Out:
#        start_index  end_index  x_top_left  y_top_left  x_bottom_right  \
# 21037         4268       4270        1990         961            2025
# 21987         4611       4613        1990         962            2023
# 29356         4217       4219        1990         962            2024
# 33544         4687       4689        1990         962            2025
# 35585         4243       4244        1580         960            1618
# 37578         4744       4746        1990         961            2025
# 38483         4787       4789        1991         960            2025
# 39408         4629       4631        1990         961            2024
# 42110         6250       6251        1287         722            1320
# 55173         4399       4400        1577         959            1620
# 56103         4201       4203        1990         961            2025
# 57040         4168       4170        1679         962            1714
# ...

# %%
combined_df['transcript'] = combined_df['transcript'].fillna("NULL")

# %%
combined_df.head(7)
# Out:
#    start_index  end_index  x_top_left  y_top_left  x_bottom_right  \
# 0           33         33         216          22             225
# 1           35         44         235          21             309
# 2           46         51         311          20             350
# 3           53         60         353          19             402
# 4           62         67         405          19             456
# 5          115        119         783          11             820
# 6          121        129         823          10             896
#
#    y_bottom_right  transcript  \
# 0              36           a
# 1              36  Employee's
# 2              35      social
# 3              34    security
# 4              33      number
# 5              26       Safe,
# 6              26   Accurate,
#
#                                            file_name
# 0  033ae477-99aa-4047-953d-4a951fc5a498_document-...
# 1  033ae477-99aa-4047-953d-4a951fc5a498_document-...
# ...

# %%
combined_df.to_csv("data_for_prediction_with_coordinate.csv")
